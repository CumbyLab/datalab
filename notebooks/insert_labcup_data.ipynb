# %% [markdown]
# # Use the DataLab API to Inject Data

# %%
import random
import warnings
from pathlib import Path
from datalab_api import DatalabClient, DuplicateItemError
import os

# You need to generate your own API key from the Datalab web interface
# and set it as an environment variable before running this script.
os.environ['DATALAB_API_KEY'] = 'tZhRZwqWhhwEjyVSVJeWitnfEPKXKArg'

def import_labcup(filename: Path, client: DatalabClient, collection_id: str = None, update_if_exists: bool = False):
    """Helper function to import a ChemInventory xlsx export into datalab, using the
    'starting_materials' item type.

    Migrated from the original version in the main datalab repository:
        https://github.com/the-grey-group/datalab/blob/43764fb494c2cc1bf9f7dc90c25594aeb79d5767/pydatalab/tasks.py#L350-L413
    Args:
        filename (Path): Path to the ChemInventory xlsx export file.
        client (DatalabClient): Datalab API client instance.
        collection_id (str, optional): Collection ID to use for the imported items. If None,
            the collection ID will be generated based on the current date.
        update_if_exists (bool, optional): If True, existing items with the same ID will
            be updated instead of raising a DuplicateItemError. Defaults to False.  
    
    Usage:
        import_labcup(Path("path/to/your/labcup_export.xlsx"), client, collection_id="my_collection", update_if_exists=True)        

    """

    warnings.warn(
        DeprecationWarning(
            "This helper is deprecated in favour of the full-fledged plugin at: https://github.com/datalab-industries/datalab-cheminventory-plugin"
        )
    )

    def _generate_random_startingmaterial_id():
        """Generate 'XX' + a random 15-length string for use as an id for starting materials
        that don't have a barcode.
        """
        yield "".join(["XX"] + random.choices("abcdefghijklmnopqrstuvwxyz0123456789", k=15))

    try:
        import pandas as pd

        inventory_df = pd.read_excel(filename)
    except ImportError as exc:
        raise ImportError(
            "Please install pandas + openpyxl to use this helper function, via `pip install datalab-api[cheminventory-helper]`"
        ) from exc
    #TODO: add variable to specify the item type, currently hardcoded to 'starting_materials'
    inventory_df["type"] = "starting_materials"
    inventory_df["item_id"] = inventory_df["Barcode"]
    # Fill missing barcodes
    inventory_df["item_id"] = inventory_df["item_id"].fillna(
        inventory_df["item_id"].apply(lambda _: next(_generate_random_startingmaterial_id()))
    )
    # Note that all other fields are inserted from the fields specified in inventory_df 

    counts = {"success": 0, "duplicate": 0, "failed": 0}
    
    # if collection_id is None, then we use the date as the name
    if collection_id is None:
        from datetime import datetime
        collection_id = f"labcup-import-{datetime.now().strftime('%d-%m-%Y')}"
        
    # Helper function to replace non-JSON-compliant values (NaN, Inf) with None    
    import math
    def sanitize_for_json(obj):
        """Recursively replace NaNs/Infs with None in nested structures."""
        if isinstance(obj, dict):
            return {k: sanitize_for_json(v) for k, v in obj.items()}
        elif isinstance(obj, list):
            return [sanitize_for_json(v) for v in obj]
        elif isinstance(obj, float) and (math.isnan(obj) or math.isinf(obj)):
            return None
        else:
            return obj
        
    def update_existing_item(item_id: str, item_data: dict, base_url: str):
        """Update an existing item using direct HTTP request."""
        import httpx
        import os
        
        try:
            response = httpx.post(
                f"{base_url}/save-item",
                json={"item_id": item_id, "data": item_data},
                follow_redirects=True,
                headers={"DATALAB-API-KEY": os.environ["DATALAB_API_KEY"]},
                timeout=30.0
            )
            response.raise_for_status()
            return True
        except Exception as e:
            print(f"Failed to update item {item_id}: {e}")
            return False
    for raw_item in inventory_df.to_dict(orient="records"):
        # clean up the item to ensure it's JSON-compliant
        item = sanitize_for_json(raw_item)  
        try:
            client.create_item(
                item["item_id"], item["type"], item, collection_id=collection_id
            )
            counts["success"] += 1
            print(f"Successfully imported item: {item['item_id']}")
        except DuplicateItemError:
            counts["duplicate"] += 1
            
            if not update_if_exists:
                print(f"Duplicate item found: {item['item_id']}, but skipping entry as no update is requested.")
            else:
                # Try to update the existing item instead
                print(f"Duplicate item found: {item['item_id']}, attempting to update...")
                
                # Get the client's base URL (assuming it's available)
                base_url = getattr(client, 'base_url', 'http://sce-chem-c01894.chem.ed.ac.uk:5001')
                
                if update_existing_item(item["item_id"], item, base_url):
                    print(f"Successfully updated item: {item['item_id']}")
                else:
                    counts["duplicate"] += 1
                    print(f"Failed to update duplicate item: {item['item_id']}")
        except Exception as exc:
            counts["failed"] += 1
            print(f"Failed to import item: {item}. Error: {exc}")
            continue

    print(f"Done: {counts=}")

# %%
# import the CLEANED data into datalab
import_labcup(filename="/home/ian/datalab-deployment/datalab/Chemicals_all_09_06_2025_updated.xlsx", client=DatalabClient("http://sce-chem-c01894.chem.ed.ac.uk:5001"))
# Out:
# /tmp/ipykernel_123709/1911046731.py:20: DeprecationWarning: This helper is deprecated in favour of the full-fledged plugin at: https://github.com/datalab-industries/datalab-cheminventory-plugin
#   warnings.warn(
# Duplicate item found: CH009014, attempting to update...
# Successfully updated item: CH009014
# Duplicate item found: CH009470, attempting to update...
# Successfully updated item: CH009470
# Duplicate item found: CH009053, attempting to update...
# Successfully updated item: CH009053
# Duplicate item found: CH009071, attempting to update...
# Successfully updated item: CH009071
# Duplicate item found: CH009017, attempting to update...
# Successfully updated item: CH009017
# Duplicate item found: CH080327, attempting to update...
# Successfully updated item: CH080327
# Duplicate item found: CH079910, attempting to update...
# Successfully updated item: CH079910
# Duplicate item found: CH079666, attempting to update...
# Successfully updated item: CH079666
# Duplicate item found: CH079665, attempting to update...
# Successfully updated item: CH079665
# Duplicate item found: CH077730, attempting to update...
# Successfully updated item: CH077730
# Duplicate item found: CH001479, attempting to update...
# Successfully updated item: CH001479
# Duplicate item found: CH078044, attempting to update...
# Successfully updated item: CH078044
# Duplicate item found: CH078045, attempting to update...
# Successfully updated item: CH078045
# Duplicate item found: CH078866, attempting to update...
# Successfully updated item: CH078866
# Duplicate item found: CH078867, attempting to update...
# Successfully updated item: CH078867
# Duplicate item found: CH078870, attempting to update...
# Successfully updated item: CH078870
# Duplicate item found: CH078869, attempting to update...
# Successfully updated item: CH078869
# Duplicate item found: CH078868, attempting to update...
# Successfully updated item: CH078868
# Duplicate item found: CH038364, attempting to update...
# Successfully updated item: CH038364
# Duplicate item found: CH090117, attempting to update...
# Successfully updated item: CH090117
# Duplicate item found: 21044173265193, attempting to update...
# Successfully updated item: 21044173265193
# Duplicate item found: CH100902, attempting to update...
# Successfully updated item: CH100902
# Duplicate item found: CH106704, attempting to update...
# Successfully updated item: CH106704
# Duplicate item found: CH109120, attempting to update...
# Successfully updated item: CH109120
# Duplicate item found: 21011174142617, attempting to update...
# Successfully updated item: 21011174142617
# Duplicate item found: CH111309, attempting to update...
# Successfully updated item: CH111309
# Duplicate item found: 21011173896980, attempting to update...
# Successfully updated item: 21011173896980
# Duplicate item found: CH094272, attempting to update...
# Successfully updated item: CH094272
# Duplicate item found: CH094411, attempting to update...
# Successfully updated item: CH094411
# Duplicate item found: CH091479, attempting to update...
# Successfully updated item: CH091479
# Duplicate item found: CH092884, attempting to update...
# Successfully updated item: CH092884
# Duplicate item found: CH083123, attempting to update...
# Successfully updated item: CH083123
# Duplicate item found: CH082378, attempting to update...
# Successfully updated item: CH082378
# Duplicate item found: CH081850, attempting to update...
# Successfully updated item: CH081850
# Duplicate item found: CH080623, attempting to update...
# Successfully updated item: CH080623
# Duplicate item found: CH082201, attempting to update...
# Successfully updated item: CH082201
# Duplicate item found: CH082316, attempting to update...
# Successfully updated item: CH082316
# Duplicate item found: CH064524, attempting to update...
# Successfully updated item: CH064524
# Duplicate item found: CH082998, attempting to update...
# Successfully updated item: CH082998
# Duplicate item found: CH087917, attempting to update...
# Successfully updated item: CH087917
# Duplicate item found: CH091547, attempting to update...
# Successfully updated item: CH091547
# Duplicate item found: CH091550, attempting to update...
# Successfully updated item: CH091550
# Duplicate item found: CH091549, attempting to update...
# Successfully updated item: CH091549
# Duplicate item found: CH091548, attempting to update...
# Successfully updated item: CH091548
# Duplicate item found: CH082847, attempting to update...
# Successfully updated item: CH082847
# Duplicate item found: CH083861, attempting to update...
# Successfully updated item: CH083861
# Duplicate item found: CH082846, attempting to update...
# Successfully updated item: CH082846
# Duplicate item found: CH085330, attempting to update...
# Successfully updated item: CH085330
# Duplicate item found: 21754110114521, attempting to update...
# Successfully updated item: 21754110114521
# Duplicate item found: CH096285, attempting to update...
# Successfully updated item: CH096285
# Duplicate item found: CH097353, attempting to update...
# Successfully updated item: CH097353
# Duplicate item found: CH097390, attempting to update...
# Successfully updated item: CH097390
# Duplicate item found: CH097472, attempting to update...
# Successfully updated item: CH097472
# Duplicate item found: CH097579, attempting to update...
# Successfully updated item: CH097579
# Duplicate item found: CH097619, attempting to update...
# Successfully updated item: CH097619
# Duplicate item found: CH097618, attempting to update...
# Successfully updated item: CH097618
# Duplicate item found: CH090074, attempting to update...
# Successfully updated item: CH090074
# Duplicate item found: CH090087, attempting to update...
# Successfully updated item: CH090087
# Duplicate item found: CH090098, attempting to update...
# Successfully updated item: CH090098
# Duplicate item found: CH090119, attempting to update...
# Successfully updated item: CH090119
# Duplicate item found: CH090132, attempting to update...
# Successfully updated item: CH090132
# Duplicate item found: CH090168, attempting to update...
# Successfully updated item: CH090168
# Duplicate item found: CH090165, attempting to update...
# Successfully updated item: CH090165
# Duplicate item found: CH090195, attempting to update...
# Successfully updated item: CH090195
# Duplicate item found: 21011174387520, attempting to update...
# Successfully updated item: 21011174387520
# Duplicate item found: CH090273, attempting to update...
# Successfully updated item: CH090273
# Duplicate item found: CH090315, attempting to update...
# Successfully updated item: CH090315
# Duplicate item found: CH090318, attempting to update...
# Successfully updated item: CH090318
# Duplicate item found: CH090321, attempting to update...
# Successfully updated item: CH090321
# Duplicate item found: CH090326, attempting to update...
# Successfully updated item: CH090326
# Duplicate item found: CH090348, attempting to update...
# Successfully updated item: CH090348
# Duplicate item found: CH090344, attempting to update...
# Successfully updated item: CH090344
# Duplicate item found: CH090345, attempting to update...
# Successfully updated item: CH090345
# Duplicate item found: CH096996, attempting to update...
# Successfully updated item: CH096996
# Duplicate item found: CH096998, attempting to update...
# Successfully updated item: CH096998
# Duplicate item found: CH096978, attempting to update...
# Successfully updated item: CH096978
# Duplicate item found: CH096951, attempting to update...
# Successfully updated item: CH096951
# Duplicate item found: CH096950, attempting to update...
# Successfully updated item: CH096950
# Duplicate item found: CH096949, attempting to update...
# Successfully updated item: CH096949
# Duplicate item found: CH096961, attempting to update...
# Successfully updated item: CH096961
# Duplicate item found: CH096960, attempting to update...
# Successfully updated item: CH096960
# Duplicate item found: CH096945, attempting to update...
# Successfully updated item: CH096945
# Duplicate item found: CH096901, attempting to update...
# Successfully updated item: CH096901
# Duplicate item found: 21011601005984, attempting to update...
# Successfully updated item: 21011601005984
# Duplicate item found: CH097234, attempting to update...
# Successfully updated item: CH097234
# Duplicate item found: CH097235, attempting to update...
# Successfully updated item: CH097235
# Duplicate item found: CH095804, attempting to update...
# Successfully updated item: CH095804
# Duplicate item found: CH095870, attempting to update...
# Successfully updated item: CH095870
# Duplicate item found: CH100018, attempting to update...
# Successfully updated item: CH100018
# Duplicate item found: CH100039, attempting to update...
# Successfully updated item: CH100039
# Duplicate item found: CH100038, attempting to update...
# Successfully updated item: CH100038
# Duplicate item found: CH100050, attempting to update...
# Successfully updated item: CH100050
# Duplicate item found: CH100057, attempting to update...
# Successfully updated item: CH100057
# Duplicate item found: CH100071, attempting to update...
# Successfully updated item: CH100071
# Duplicate item found: CH100081, attempting to update...
# Successfully updated item: CH100081
# Duplicate item found: CH10093, attempting to update...
# Successfully updated item: CH10093
# Duplicate item found: CH100097, attempting to update...
# Successfully updated item: CH100097
# Duplicate item found: CH100102, attempting to update...
# Successfully updated item: CH100102
# Duplicate item found: 21011174184822, attempting to update...
# Successfully updated item: 21011174184822
# Duplicate item found: CH100133, attempting to update...
# Successfully updated item: CH100133
# Duplicate item found: CH100147, attempting to update...
# Successfully updated item: CH100147
# Duplicate item found: CH100221, attempting to update...
# Successfully updated item: CH100221
# Duplicate item found: 21011601005229, attempting to update...
# Successfully updated item: 21011601005229
# Duplicate item found: CH100241, attempting to update...
# Successfully updated item: CH100241
# Duplicate item found: CH100311, attempting to update...
# Successfully updated item: CH100311
# Duplicate item found: CH100646, attempting to update...
# Successfully updated item: CH100646
# Duplicate item found: CH100681, attempting to update...
# Successfully updated item: CH100681
# Duplicate item found: CH100689, attempting to update...
# Successfully updated item: CH100689
# Duplicate item found: CH095912, attempting to update...
# Successfully updated item: CH095912
# Duplicate item found: CH100697, attempting to update...
# Successfully updated item: CH100697
# Duplicate item found: CH100690, attempting to update...
# Successfully updated item: CH100690
# Duplicate item found: CH100701, attempting to update...
# Successfully updated item: CH100701
# Duplicate item found: CH100757, attempting to update...
# Successfully updated item: CH100757
# Duplicate item found: CH100752, attempting to update...
# Successfully updated item: CH100752
# Duplicate item found: CH100774, attempting to update...
# Successfully updated item: CH100774
# Duplicate item found: CH100777, attempting to update...
# Successfully updated item: CH100777
# Duplicate item found: CH100792, attempting to update...
# Successfully updated item: CH100792
# Duplicate item found: CH100802, attempting to update...
# Successfully updated item: CH100802
# Duplicate item found: CH100803, attempting to update...
# Successfully updated item: CH100803
# Duplicate item found: CH100804, attempting to update...
# Successfully updated item: CH100804
# Duplicate item found: 21754110139104, attempting to update...
# Successfully updated item: 21754110139104
# Duplicate item found: CH100841, attempting to update...
# Successfully updated item: CH100841
# Duplicate item found: CH100843, attempting to update...
# Successfully updated item: CH100843
# Duplicate item found: CH100842, attempting to update...
# Successfully updated item: CH100842
# Duplicate item found: CH100850, attempting to update...
# Successfully updated item: CH100850
# Duplicate item found: CH100856, attempting to update...
# Successfully updated item: CH100856
# Duplicate item found: CHTEST01, attempting to update...
# Successfully updated item: CHTEST01
# Duplicate item found: CH100867, attempting to update...
# Successfully updated item: CH100867
# Duplicate item found: CH100879, attempting to update...
# Successfully updated item: CH100879
# Duplicate item found: CH100885, attempting to update...
# Successfully updated item: CH100885
# Duplicate item found: CH100887, attempting to update...
# Successfully updated item: CH100887
# Duplicate item found: CH100904, attempting to update...
# Successfully updated item: CH100904
# Duplicate item found: CH100908, attempting to update...
# Successfully updated item: CH100908
# Duplicate item found: CH100927, attempting to update...
# Successfully updated item: CH100927
# Duplicate item found: CH100923, attempting to update...
# Successfully updated item: CH100923
# Duplicate item found: CH100934, attempting to update...
# Successfully updated item: CH100934
# Duplicate item found: CH100944, attempting to update...
# Successfully updated item: CH100944
# Duplicate item found: CH101891, attempting to update...
# Successfully updated item: CH101891
# Duplicate item found: CH101907, attempting to update...
# Successfully updated item: CH101907
# Duplicate item found: CH101908, attempting to update...
# Successfully updated item: CH101908
# Duplicate item found: CH101923, attempting to update...
# Successfully updated item: CH101923
# Duplicate item found: CH101962, attempting to update...
# Successfully updated item: CH101962
# Duplicate item found: CH102001, attempting to update...
# Successfully updated item: CH102001
# Duplicate item found: CH095913, attempting to update...
# Successfully updated item: CH095913
# Duplicate item found: CH102009, attempting to update...
# Successfully updated item: CH102009
# Duplicate item found: CH102011, attempting to update...
# Successfully updated item: CH102011
# Duplicate item found: CH102013, attempting to update...
# Successfully updated item: CH102013
# Duplicate item found: CH102021, attempting to update...
# Successfully updated item: CH102021
# Duplicate item found: CH102037, attempting to update...
# Successfully updated item: CH102037
# Duplicate item found: CH102047, attempting to update...
# Successfully updated item: CH102047
# Duplicate item found: CH102070, attempting to update...
# Successfully updated item: CH102070
# Duplicate item found: 21044173166469, attempting to update...
# Successfully updated item: 21044173166469
# Duplicate item found: CH102084, attempting to update...
# Successfully updated item: CH102084
# Duplicate item found: 21011173934408, attempting to update...
# Successfully updated item: 21011173934408
# Duplicate item found: CH102116, attempting to update...
# Successfully updated item: CH102116
# Duplicate item found: CH102138, attempting to update...
# Successfully updated item: CH102138
# Duplicate item found: CH102183, attempting to update...
# Successfully updated item: CH102183
# Duplicate item found: CH102170, attempting to update...
# Successfully updated item: CH102170
# Duplicate item found: CH102211, attempting to update...
# Successfully updated item: CH102211
# Duplicate item found: 21011173925376, attempting to update...
# Successfully updated item: 21011173925376
# Duplicate item found: CH102255, attempting to update...
# Successfully updated item: CH102255
# Duplicate item found: CH102280, attempting to update...
# Successfully updated item: CH102280
# Duplicate item found: CH102308, attempting to update...
# Successfully updated item: CH102308
# Successfully imported item: CH102317
# Successfully imported item: CH102318
# Successfully imported item: CH102378
# Successfully imported item: CH102396
# Successfully imported item: CH102398
# Successfully imported item: 21905850001972
# Successfully imported item: CH102434
# Successfully imported item: CH1024507
# Successfully imported item: CH102470
# Successfully imported item: 21011601010643
# Successfully imported item: CH102508
# Successfully imported item: CH104437
# Successfully imported item: CH104486
# Successfully imported item: CH104488
# Successfully imported item: CH104495
# Successfully imported item: CH104514
# Successfully imported item: CHCH104551
# Successfully imported item: 21011181054545
# Successfully imported item: 21720660135859
# Successfully imported item: CH1044620
# Successfully imported item: CH104617
# Successfully imported item: CH088842
# Successfully imported item: CH088857
# Successfully imported item: CH104638
# Successfully imported item: CH104642
# Successfully imported item: CH104658
# Successfully imported item: CH104679
# Successfully imported item: CH104693
# Successfully imported item: CH104707
# Successfully imported item: CH104713
# Successfully imported item: CH104728
# Successfully imported item: CH104733
# Successfully imported item: CH104736
# Successfully imported item: CH104819
# Successfully imported item: CH104844
# Successfully imported item: CH104862
# Successfully imported item: CH104863
# Successfully imported item: CH104864
# Successfully imported item: CH104865
# Successfully imported item: CH104866
# Successfully imported item: CH104917
# Successfully imported item: CH104923
# Successfully imported item: CH104924
# Successfully imported item: CH104942
# Successfully imported item: CH104976
# Successfully imported item: CH104992
# Successfully imported item: CH105004
# Successfully imported item: CH105022
# Successfully imported item: CH105030
# Successfully imported item: CH098364
# Successfully imported item: CH105046
# Successfully imported item: CH105054
# Successfully imported item: CH105085
# Successfully imported item: CH105107
# Successfully imported item: CH105142
# Successfully imported item: CH105154
# Successfully imported item: CH105183
# Successfully imported item: CH105225
# Successfully imported item: CH095340
# Successfully imported item: CH095341
# Successfully imported item: 21012170017118
# Successfully imported item: CH105275
# Successfully imported item: CH105288
# Successfully imported item: 21720111094636
# Successfully imported item: CH105309
# Successfully imported item: CH105323
# Successfully imported item: CH105341
# Successfully imported item: CH105346
# Successfully imported item: CH105372
# Successfully imported item: CH095344
# Successfully imported item: CH105386
# Successfully imported item: CH105389
# Successfully imported item: CH105414
# Successfully imported item: CH105426
# Successfully imported item: CH105428
# Successfully imported item: CH105498
# Successfully imported item: CH105502
# Successfully imported item: CH105518
# Successfully imported item: CH105537
# Successfully imported item: CH105540
# Successfully imported item: CH105547
# Successfully imported item: CH105550
# Successfully imported item: CH105586
# Successfully imported item: 21011176085974
# Successfully imported item: CH105601
# Successfully imported item: CH105602
# Successfully imported item: CH105613
# Successfully imported item: CH105629
# Successfully imported item: CH105651
# Successfully imported item: CH105652
# Successfully imported item: CH106011
# Successfully imported item: CH095355
# Successfully imported item: CH106028
# Successfully imported item: CH106034
# Successfully imported item: CH106039
# Successfully imported item: CH106059
# Successfully imported item: CH106060
# Successfully imported item: CH106067
# Successfully imported item: CH106068
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 # import the CLEANED data into datalab
# ----> 2 import_labcup(filename="/home/ian/datalab-deployment/datalab/Chemicals_all_09_06_2025_updated.xlsx", client=DatalabClient("http://sce-chem-c01894.chem.ed.ac.uk:5001"))
#
# Cell In[16], line 90, in import_labcup(filename, client, collection_id, update_if_exists)
#      88 item = sanitize_for_json(raw_item)
#      89 try:
# ---> 90     client.create_item(
#      91         item["item_id"], item["type"], item, collection_id=collection_id
#      92     )
#      93     counts["success"] += 1
#      94     print(f"Successfully imported item: {item['item_id']}")
#
# File ~/datalab-deployment/datalab/pydatalab/.venv/lib/python3.11/site-packages/datalab_api/_base.py:30, in pretty_displayer.<locals>.rich_wrapper(self, *args, **kwargs)
#      28 display = kwargs.pop("display", False)
#      29 page_limit = kwargs.pop("page_limit", 10)
# ---> 30 result = method(self, *args, **kwargs)
#      31 if display:
#      32     blocks = None
#
# File ~/datalab-deployment/datalab/pydatalab/.venv/lib/python3.11/site-packages/datalab_api/__init__.py:180, in DatalabClient.create_item(self, item_id, item_type, item_data, collection_id)
#     177     new_item["collections"].append({"immutable_id": collection_immutable_id})
#     179 create_item_url = f"{self.datalab_api_url}/new-sample/"
# --> 180 create_item_resp = self.session.post(
#     181     create_item_url,
#     182     json={"new_sample_data": new_item, "generate_id_automatically": item_id is None},
#     183     follow_redirects=True,
#     184 )
#     185 try:
#     186     created_item = create_item_resp.json()
#
# File ~/datalab-deployment/datalab/pydatalab/.venv/lib/python3.11/site-packages/httpx/_client.py:1144, in Client.post(self, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1123 def post(
#    1124     self,
#    1125     url: URL | str,
#    (...)   1137     extensions: RequestExtensions | None = None,
#    1138 ) -> Response:
#    1139     """
#    1140     Send a `POST` request.
#    1141
#    1142     **Parameters**: See `httpx.request`.
#    1143     """
# -> 1144     return self.request(
#    1145         "POST",
#    1146         url,
#    1147         content=content,
#    1148         data=data,
#    1149         files=files,
#    1150         json=json,
#    1151         params=params,
#    1152         headers=headers,
#    1153         cookies=cookies,
#    1154         auth=auth,
#    1155         follow_redirects=follow_redirects,
#    1156         timeout=timeout,
#    1157         extensions=extensions,
#    1158     )
#
# File ~/datalab-deployment/datalab/pydatalab/.venv/lib/python3.11/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/datalab-deployment/datalab/pydatalab/.venv/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/datalab-deployment/datalab/pydatalab/.venv/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/datalab-deployment/datalab/pydatalab/.venv/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/datalab-deployment/datalab/pydatalab/.venv/lib/python3.11/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/datalab-deployment/datalab/pydatalab/.venv/lib/python3.11/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/datalab-deployment/datalab/pydatalab/.venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/datalab-deployment/datalab/pydatalab/.venv/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/datalab-deployment/datalab/pydatalab/.venv/lib/python3.11/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/datalab-deployment/datalab/pydatalab/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/datalab-deployment/datalab/pydatalab/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/datalab-deployment/datalab/pydatalab/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/datalab-deployment/datalab/pydatalab/.venv/lib/python3.11/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/datalab-deployment/datalab/pydatalab/.venv/lib/python3.11/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %% [markdown]
# # Database Connection Troubleshoot
#
# If we run into issues, it might be because the database is not running or running at a different port than we think.

# %%
# Additional troubleshooting - run these commands in a terminal
import subprocess
import os

def run_command(command):
    """Run a shell command and return the output"""
    try:
        result = subprocess.run(command, shell=True, capture_output=True, text=True, timeout=10)
        return result.stdout, result.stderr, result.returncode
    except subprocess.TimeoutExpired:
        return "", "Command timed out", 1
    except Exception as e:
        return "", str(e), 1

# Check if MongoDB is running locally
print("=== Checking if MongoDB is running locally ===")
stdout, stderr, code = run_command("sudo systemctl status mongod")
if code == 0:
    print("MongoDB service status:")
    print(stdout[:500] + "..." if len(stdout) > 500 else stdout)
else:
    print("MongoDB service not found or not running locally")
    
# Check if port 27017 is listening
print("\n=== Checking if port 27017 is in use ===")
stdout, stderr, code = run_command("netstat -tuln | grep 27017")
if stdout:
    print("Port 27017 status:")
    print(stdout)
else:
    print("Port 27017 is not listening")

# Test DNS resolution
print("\n=== Testing DNS resolution ===")
stdout, stderr, code = run_command("nslookup sce-chem-c01894.chem.ed.ac.uk")
if code == 0:
    print("DNS resolution successful:")
    print(stdout)
else:
    print("DNS resolution failed:")
    print(stderr)

# Test ping
print("\n=== Testing connectivity ===")
stdout, stderr, code = run_command("ping -c 3 sce-chem-c01894.chem.ed.ac.uk")
if code == 0:
    print("Ping successful:")
    print(stdout)
else:
    print("Ping failed:")
    print(stderr)
# Out:
# === Checking if MongoDB is running locally ===
# MongoDB service not found or not running locally
#
# === Checking if port 27017 is in use ===
# Port 27017 is not listening
#
# === Testing DNS resolution ===
# DNS resolution successful:
# Server:		127.0.0.53
# Address:	127.0.0.53#53
#
# Name:	sce-chem-c01894.chem.ed.ac.uk
# Address: 127.0.1.1
#
#
#
# === Testing connectivity ===
# Ping successful:
# PING sce-chem-c01894.chem.ed.ac.uk (127.0.1.1) 56(84) bytes of data.
# 64 bytes from sce-chem-c01894.chem.ed.ac.uk (127.0.1.1): icmp_seq=1 ttl=64 time=0.023 ms
# 64 bytes from sce-chem-c01894.chem.ed.ac.uk (127.0.1.1): icmp_seq=2 ttl=64 time=0.058 ms
# 64 bytes from sce-chem-c01894.chem.ed.ac.uk (127.0.1.1): icmp_seq=3 ttl=64 time=0.061 ms
#
# --- sce-chem-c01894.chem.ed.ac.uk ping statistics ---
# 3 packets transmitted, 3 received, 0% packet loss, time 2061ms
# rtt min/avg/max/mdev = 0.023/0.047/0.061/0.017 ms
